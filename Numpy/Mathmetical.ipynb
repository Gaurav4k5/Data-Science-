# %%
import numpy as np 
arr = np.array([3,4,6,8,90])

# %%
np.mean(arr)
# Out:
# np.float64(22.2)

# %%
np.std(arr)
# Out:
# np.float64(33.94348243772286)

# %%
np.var(arr)
# Out:
# np.float64(1152.1599999999999)

# %%
np.min(arr)
# Out:
# np.int64(3)

# %%
np.prod(arr)
# Out:
# np.int64(51840)

# %%
np.median(arr)
# Out:
# np.float64(6.0)

# %%
np.percentile(arr, 30) # For the 30th percentile (median)
# Out:
# np.float64(4.4)

# %%
np.argmin(arr)
# Out:
# np.int64(0)

# %%
np.argmax(arr)
# Out:
# np.int64(4)
