# %%
import numpy as np
arr = np.array([[1,2,3], [2,4,5], [4,3,6], [3,5,8]])
arr
# Out:
# array([[1, 2, 3],
#        [2, 4, 5],
#        [4, 3, 6],
#        [3, 5, 8]])

# %%
flat = arr.flatten()
flat # persuing in one line
# Out:
# array([1, 2, 3, 2, 4, 5, 4, 3, 6, 3, 5, 8])

# %%
flat[0]
# Out:
# np.int64(1)

# %%
flat[3]
# Out:
# np.int64(2)

# %%
flat[4:8]
# Out:
# array([4, 5, 4, 3])

# %%
flat
# Out:
# array([1, 2, 3, 2, 4, 5, 4, 3, 6, 3, 5, 8])

# %%
b = flat[3:7].copy() # this in not a sliice becouse we using copy method to get the copy

# %%
b
# Out:
# array([2, 4, 5, 4])

# %%
b[0] = 121484
b
# Out:
# array([121484,      4,      5,      4])

# %%
arr2 = np.array([10, 20, 30, 40, 50, 60, 70])

# %%
arr2[[2,4,5]]
# Out:
# array([30, 50, 60])

# %%
arr2[arr2>32]
# Out:
# array([40, 50, 60, 70])
