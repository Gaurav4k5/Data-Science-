# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                   Film  Year              Genre  \
# 0           Aamir Khan                     PK  2014      Comedy/Sci-Fi
# 1          Salman Khan      Bajrangi Bhaijaan  2015       Drama/Action
# 2       Shah Rukh Khan                  Jawan  2023    Action/Thriller
# 3        Ranbir Kapoor                 Animal  2023       Action/Drama
# 4        Vicky Kaushal                Chhaava  2025   Historical/Drama
# 5        Rajkummar Rao                Stree 2  2024      Horror/Comedy
# 6           Sunny Deol                Gadar 2  2023       Action/Drama
# 7        Ranbir Kapoor                  Sanju  2018          Biography
# 8          Salman Khan                 Sultan  2016       Sports/Drama
# 9       Hrithik Roshan                    War  2019    Action/Thriller
# 10       Shahid Kapoor            Kabir Singh  2019      Romance/Drama
# 11        Akshay Kumar         Mission Mangal  2019       Drama/Sci-Fi
# ...

# %%
df = df[df["IMDb"]>7.0]

# %%
df
# Out:
#                  Actor                   Film  Year              Genre  \
# 0           Aamir Khan                     PK  2014      Comedy/Sci-Fi
# 1          Salman Khan      Bajrangi Bhaijaan  2015       Drama/Action
# 4        Vicky Kaushal                Chhaava  2025   Historical/Drama
# 7        Ranbir Kapoor                  Sanju  2018          Biography
# 8          Salman Khan                 Sultan  2016       Sports/Drama
# 11        Akshay Kumar         Mission Mangal  2019       Drama/Sci-Fi
# 12          Ajay Devgn                Tanhaji  2020  Historical/Action
# 16          Alia Bhatt                  Raazi  2018     Thriller/Drama
# 17        Akshay Kumar  Toilet: Ek Prem Katha  2017       Drama/Comedy
# 18  Ayushmann Khurrana             Badhaai Ho  2018       Comedy/Drama
#
#     Boxoffice (Cr)  IMDb
# 0              750   8.1
# 1              922   8.1
# 4              808   7.3
# 7              586   7.6
# 8              615   7.1
# 11             290   7.1
# ...

# %%
df.to_csv("data_updateIndex.csv", index=False)

# %% [markdown]
# # With Excel

# %%
df = pd.read_excel("data.xlsx")

# %%
df
# Out:
#        Name  School  Marks
# 0   shubham     PPY     55
# 1  manjeet      JJK     44
# 2    nikhil    JJHF     79
# 3    sumit      KDF     48
# 4     manas    KJFJ     35
# 5   saurabh  KJEFEF     95

# %%
data  = [
  {"id": 1, "name": "Astra", "role": "Navigator", "active": "true"},
  {"id": 2, "name": "Echo", "role": "Communications", "active": "false"},
  {"id": 3, "name": "Nova", "role": "Engineer", "active": "true"},
  {"id": 4, "name": "Orion", "role": "Pilot", "active": "true}
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 data  = [
# ----> 2   {"id": 1, "name": "Astra", "role": "Navigator", "active": true},
#       3   {"id": 2, "name": "Echo", "role": "Communications", "active": false},
#       4   {"id": 3, "name": "Nova", "role": "Engineer", "active": true},
#       5   {"id": 4, "name": "Orion", "role": "Pilot", "active": true}
#       6 ]
#
# NameError: name 'true' is not defined
